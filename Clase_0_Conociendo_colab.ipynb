# %% [markdown]
# #Titulo
# ##Titulo
# ###Titulo
# hola😊
# * hola
#
#
# ```
# if (condicion):
#  ...
#  else:
#  ....
# ```

# %% [markdown]
# #INPUT
# Input es una funcion, que permite ingresar datos.
#
# Posee 3 funciones
# 1. Lee: Se puede ingresar informacion
# 2. Almacena: Guarda la informacion en una variable (var)
# 3. declara: Todos los datos se vuelven string
#
# Sintaxis
#
# ```
# var=input(Aquí va su impresion)
# ```
#
# Si se desea realizar una lectura de un tipo de dato diferente a string, se debe realizar una conversion de datos.
# Para ello, coloque el tipo de dato que desea convertir, y encierre el tipo original de dato entre parentesis.
#
#
# ```
# var=int (input()) #aqui se va a transformar un dato de string a entero
# var2=float (input()) #Se transforma de string a decimal
# var3=bool (input())#Se transforma de string a booleano
# ```

# %% [markdown]
# ##Saludando al mundo

# %%
print("Hola mundo")
# Out:
# Hola mundo

# %%
nombre = input("como te llamas?")
# Out:
# como te llamas?Valentina

# %%
nombre
# Out:
# 'Valentina'

# %%
edad = int(input("cuantos años tienes? "))
# Out:
# cuantos años tienes? 17

# %%
edad
# Out:
# 17

# %%
edadd =int(input("Cuantos años tiene tu compañero?"))
# Out:
# Cuantos años tiene tu compañero?17

# %%
edadd
# Out:
# 17

# %%
print ("la suma de ambas edades es: ");
suma = edad + edadd
suma
# Out:
# la suma de ambas edades es:
# 34
