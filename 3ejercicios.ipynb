# %% [markdown]
# <a href="https://colab.research.google.com/github/Valentina-Gallo/PROGCOM_B_2026/blob/main/3ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##ejercicio 1

# %%
base = float(input("Introduce la base: "))
altura = float(input("Introduce la altura: "))

area = (base * altura) / 2

print(f"El área es: {area}" )
# Out:
# Introduce la base: 23
# Introduce la altura: 4
# El área es: 46.0

# %% [markdown]
# ##Ejercicio 2

# %%
nombre = input("Introduce tu nombre: ")
edad = int(input("Introduce tu edad: "))

prioridad = "Tiene prioridad en la fila." if edad >= 70 else "Por favor, espere su turno normalmente."

print(f"\nHola, {nombre}. {prioridad}")
# Out:
# Introduce tu nombre: vale
# Introduce tu edad: 567
#
# Hola, vale. Tiene prioridad en la fila.

# %% [markdown]
# ##Ejercicio 3

# %%
C = int(input("Introduce celsius: "))
F = (C * 9/5) + 32
print(f"en Farenheit es: {F}" )
# Out:
# Introduce celsius: 32
# en Farenheit es: 89.6
